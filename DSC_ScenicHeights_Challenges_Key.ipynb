# %%
# Create a list your five favorite holiday presents, and using a for loop, print them all out
myFavoriteHolidayFoods = ['cookies', 'mashed potatoes', 'fried fish', 'biryani', 'ham']

for food in myFavoriteHolidayFoods:
    print(food)
# Out:
# cookies
# mashed potatoes
# fried fish
# biryani
# ham

# %%
# Create a program using input()that lists out all of the perfect squares from one to a number that you input
n = int(input('to what number?: '))
i = 0

while i <= n:
    print((i**2))
    i += 1
# Out:
# to what number?: 5
# 0
# 1
# 4
# 9
# 16
# 25

# %%
# Create a program that adds any two numbers together that you input
a = int(input('enter your first number: '))
b = int(input('enter your second number: '))

print(a+b)
# Out:
# enter your first number: 2
# enter your second number: 6
# 8

# %%
# Then, create more programs that do the same thing, but for the other mathematical operations
# subtraction
a = int(input('enter your first number: '))
b = int(input('enter your second number: '))

print(a-b)

# multiplication
a = int(input('enter your first number: '))
b = int(input('enter your second number: '))

print(a*b)

# division
a = int(input('enter your first number: '))
b = int(input('enter your second number: '))

print(a/b)
# Out:
# enter your first number: 2
# enter your second number: 6
# -4
# enter your first number: 2
# enter your second number: 6
# 12
# enter your first number: 2
# enter your second number: 6
# 0.3333333333333333

# %%
# Combine all of these individual programs together, and make a program that asks you if you want to do addition, subtraction, multiplication, or division. Then, based on an input, your program should choose which operation to perform, then ask you to input numbers which it performs the operation on (HINT: use an if statement and if statements)
a = int(input('enter your first number: '))
b = int(input('enter your second number: '))

operation = input("enter \n'a' if you want to do addition, \n's' for subtraction, \n'm' for multiplication, \n or 'd' for division:  ")

if operation == 'a':
    print(a+b)
elif operation == 's':
    print(a-b)
elif operation == 'm':
    print(a*b)
elif operation == 'd':
    print(a/b)
else:
    prin('try again')
# Out:
# enter your first number: 2
# enter your second number: 6
# enter
# 'a' if you want to do addition,
# 's' for subtraction,
# 'm' for multiplication,
#  or 'd' for division:  m
# 12
